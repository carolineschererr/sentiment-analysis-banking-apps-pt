# %% [markdown]
# # Coleta de dados

# %% [markdown]
# Este notebook contém o script utilizado para fazer scraping dos dados na Play Store.

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app, Sort, reviews
import pandas as pd

# %%
app_id = "com.itau" # trocar para o id de outros bancos para fazer scraping dos seus reviews

avaliacoes, _ = reviews(
    app_id,
    lang='pt',
    country='br',
    sort=Sort.NEWEST,
    count=50 # define o número de reviews coletados
)

# %%
avaliacoes
# Out:
# [{'reviewId': 'fead5d3d-8353-44f3-9d02-777694ef5e1b',
#   'userName': 'José Marcos Alves Dias Alves Dias',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLRRcxLFdBNEVPdNeRomQIr-NfZpiU5Rxs4shijoJKIZMkyBw=mo',
#   'content': 'muito bom 👍',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '7.098.4',
#   'at': datetime.datetime(2025, 4, 21, 0, 36, 1),
#   'replyContent': '“Olá! Que ótimo receber seu elogio hoje 😊 Agradecemos por tirar um tempo para nos avaliar, é incrível poder fazer parte de sua rotina facilitando o controle das suas finanças. Qualquer dúvida, conte com a gente, combinado? ”',
#   'repliedAt': datetime.datetime(2025, 4, 21, 0, 46, 2),
#   'appVersion': '7.098.4'},
#  {'reviewId': '49dd77c2-592a-429f-adfd-33403ab11ef2',
#   'userName': 'Patrick Pedro bonetti',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUzPpDbWjPqQqYwpLbLpNEbu1cX2apIgyK9si1mrs6A8e2GavU',
#   'content': 'este aplicativo é muito bom',
# ...

# %%
df_avaliacoes = pd.DataFrame(avaliacoes)

# %%
df_avaliacoes.score.value_counts()
# Out:
# score
# 5    27
# 1    16
# 2     3
# 3     3
# 4     1
# Name: count, dtype: int64

# %%
df_avaliacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              50 non-null     object
#  1   userName              50 non-null     object
#  2   userImage             50 non-null     object
#  3   content               50 non-null     object
#  4   score                 50 non-null     int64
#  5   thumbsUpCount         50 non-null     int64
#  6   reviewCreatedVersion  43 non-null     object
#  7   at                    50 non-null     datetime64[ns]
#  8   replyContent          26 non-null     object
#  9   repliedAt             26 non-null     datetime64[ns]
#  10  appVersion            43 non-null     object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 4.4+ KB

# %%
df_avaliacoes = df_avaliacoes.drop_duplicates(subset=['reviewId'])

# %%
df_avaliacoes.to_csv('avaliacoes_itau_total.csv', index=False, escapechar='\\')

# %%
df_avaliacoes = df_avaliacoes[df_avaliacoes['score'] < 5]

# %%
df_avaliacoes.to_csv('avaliacoes_itau_1_4.csv', index=False, escapechar='\\')
